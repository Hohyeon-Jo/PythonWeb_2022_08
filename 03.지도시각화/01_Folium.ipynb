# %% [markdown]
# <h1>Folium 지도 시각화

# %%
import folium
folium.__version__
# Out:
# Failed to start the Kernel.
#
# c:\anaconda\lib\site-packages\traitlets\traitlets.py:2202: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#
#   warn(
#
# c:\anaconda\lib\site-packages\traitlets\traitlets.py:2157: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '5eddfbb8-e8f8-44b7-865c-932cc3493ae9' instead of 'b"5eddfbb8-e8f8-44b7-865c-932cc3493ae9"'.
#
#   warn(
#
# Bad file descriptor (bundled\zeromq\src\epoll.cpp:100).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
map = folium.Map(location=[35.15984075465654,126.85178409306049],zoom_start=30)
folium.Marker(
    location=[35.15984075465654,126.85178409306049],
    popup=folium.Popup('광주광역시 내방로 111',max-width=200),
    tooltip='광주광역시청'
).add_to(map)
map
# Out:
# Failed to start the Kernel.
#
# c:\anaconda\lib\site-packages\traitlets\traitlets.py:2202: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#
#   warn(
#
# c:\anaconda\lib\site-packages\traitlets\traitlets.py:2157: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use 'ea227b3a-30bb-42fc-85a2-2958b7c0df86' instead of 'b"ea227b3a-30bb-42fc-85a2-2958b7c0df86"'.
#
#   warn(
#
# Bad file descriptor (bundled\zeromq\src\epoll.cpp:100).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Open street map에 광주광역시청과 구청을 표시
# 지도 스타일 변화. tiles
# 마커 아이콘 변경. folium icon을 검색하면 다양한 정류를 찾을 수 있다.
# 마커 말고도 Circle, CircleMarker 등 많음
from folium.features import CustomIcon
from folium.features import DivIcon
map = folium.Map(location=[35.159841, 126.851784],tiles="Stamen Toner", zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width = 200),
    tooltip='광주광역시청',
    # icon = CustomIcon('다운로드.jpg', icon_size = (80, 80))
).add_to(map)
folium.Marker(
    location=[35.14610731846924, 126.92331464592247],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width = 200),
    tooltip='광주광역시 동구청',
    icon = DivIcon(icon_size=(80,20), icon_anchor = (0,0),
                   html='<div style="font-size: 14pt"><bold>광주 동구청</bold></div>')
).add_to(map)
folium.Circle(
    radius=200,
    location=[35.152089096162236, 126.88985826388209],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width = 200),
    tooltip='광주광역시 서구청',
    color="magenta",
    fill=True,
).add_to(map)
folium.CircleMarker(
    location=[35.13290098068543, 126.90257332634087],
    radius=20,
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width = 200),
    color="#3186CC",
    tooltip='광주광역시 남구청',
    fill=True,
    fill_color="#3186CC",
).add_to(map)
folium.Marker(
    location=[35.17410046937537, 126.91215706204946],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width = 200),
    tooltip='광주광역시 북구청'
).add_to(map)
folium.Marker(
    location=[35.13955198869462, 126.79380680502933],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width = 200),
    tooltip='광주광역시 광산구청',
    # icon = folium.Icon('blue', icon = 'plane')
).add_to(map)
#지도에 제목 넣기
title_html = '<h3 align = "center">광주광역시 주요 행정기관</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46b0aa2b12626a9b3d4065725b7282c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;h3 align = &quot;center&quot;&gt;광주광역시 주요 행정기관&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46b0aa2b12626a9b3d4065725b7282c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_46b0aa2b12626a9b3d4065725b7282c5 = L.map(
#                 &quot;map_46b0aa2b12626a9b3d4065725b7282c5&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50a0fd15c8c766bb38f8bed0c174f73e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46b0aa2b12626a9b3d4065725b7282c5);
#
#
#             var marker_47909e33ccea0610469292e30c9b9905 = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_46b0aa2b12626a9b3d4065725b7282c5);
#
#
#         var popup_959af406811ca465f5f3765ae6aff002 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_ad4418a4d7ddce1b9b50d8d96020785e = $(`&lt;div id=&quot;html_ad4418a4d7ddce1b9b50d8d96020785e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_959af406811ca465f5f3765ae6aff002.setContent(html_ad4418a4d7ddce1b9b50d8d96020785e);
#
#
#         marker_47909e33ccea0610469292e30c9b9905.bindPopup(popup_959af406811ca465f5f3765ae6aff002)
#         ;
#
#
#
#
#             marker_47909e33ccea0610469292e30c9b9905.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25fa59270d7a2b7556c99eaa41386140 = L.marker(
#                 [35.14610731846924, 126.92331464592247],
#                 {}
#             ).addTo(map_46b0aa2b12626a9b3d4065725b7282c5);
#
#
#             var div_icon_1317077043eedbec586d285ca1b1c83e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt\&quot;\u003e\u003cbold\u003e\uad11\uc8fc \ub3d9\uad6c\uccad\u003c/bold\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [80, 20]});
#             marker_25fa59270d7a2b7556c99eaa41386140.setIcon(div_icon_1317077043eedbec586d285ca1b1c83e);
#
#
#         var popup_087bb526b77491ae41158f09f76caee4 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_941304050f3c964011097136eb32b80c = $(`&lt;div id=&quot;html_941304050f3c964011097136eb32b80c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_087bb526b77491ae41158f09f76caee4.setContent(html_941304050f3c964011097136eb32b80c);
#
#
#         marker_25fa59270d7a2b7556c99eaa41386140.bindPopup(popup_087bb526b77491ae41158f09f76caee4)
#         ;
#
#
#
#
#             marker_25fa59270d7a2b7556c99eaa41386140.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_af3395003bcb2075c477d2fb72a6d9df = L.circle(
#                 [35.152089096162236, 126.88985826388209],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_46b0aa2b12626a9b3d4065725b7282c5);
#
#
#         var popup_0d44fa354a00f911eceb960bdf7576d2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_aee8dcd924edb11cc17f691bae30ee03 = $(`&lt;div id=&quot;html_aee8dcd924edb11cc17f691bae30ee03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_0d44fa354a00f911eceb960bdf7576d2.setContent(html_aee8dcd924edb11cc17f691bae30ee03);
#
#
#         circle_af3395003bcb2075c477d2fb72a6d9df.bindPopup(popup_0d44fa354a00f911eceb960bdf7576d2)
#         ;
#
#
#
#
#             circle_af3395003bcb2075c477d2fb72a6d9df.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_03a8a3a8748872fd0abf2ffa34b6a6f
