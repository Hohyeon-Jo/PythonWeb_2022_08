# %% [markdown]
# # Simple App - Ngrok로 연결

# %% [markdown]
# ### Ngrok를 사용하기 위한 과정

# %%
# !pip install flask-ngrok
#!pip install flask-ngrok > /dev/null 2>&1      #화면에 뜨는거 싫으면 이거 쓰면 됨
# Out:
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from flask-ngrok) (2.27.1)
# Requirement already satisfied: Flask>=0.8 in c:\anaconda\lib\site-packages (from flask-ngrok) (1.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\anaconda\lib\site-packages (from Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\anaconda\lib\site-packages (from Flask>=0.8->flask-ngrok) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\anaconda\lib\site-packages (from Flask>=0.8->flask-ngrok) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\anaconda\lib\site-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from click>=5.1->Flask>=0.8->flask-ngrok) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->flask-ngrok) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->flask-ngrok) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\anaconda\lib\site-packages (from requests->flask-ngrok) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->flask-ngrok) (3.3)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
# !pip install pyngrok #ngrok 명령어 설치
# Out:
# ERROR: Invalid requirement: '#ngrok'

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-fe18fdca-6fa9-4097-b26a-de03a787f020" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe18fdca-6fa9-4097-b26a-de03a787f020">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ngrok_auth.txt to ngrok_auth.txt

# %%
with open('ngrok_auth.txt') as nf:
  ngrok_auth = nf.read()

# %%
# !ngrok authtoken $ngrok_auth
# Out:
# 'ngrok' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### 이 이후부터는 심플 웹 서버를 만드는 과정

# %%
from flask import Flask
from flask_ngrok import run_with_ngrok  # ngrok를 사용할 때만 사용

# %%
app = Flask(__name__)
run_with_ngrok(app)   # ngrok를 사용할 때만 사용, Start ngrok when app is running

# %%
@app.route('/')
def hello():
  return "<h1>Hello World!</h1>"
if __name__ == '__main__':
  app.run() #막혀있기 때문에 ngrok로 뚫린 Running on 으로 실행
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://81d6-121-66-158-210.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [17/Aug/2022 11:37:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2022 11:37:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2022 11:37:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2022 11:37:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2022 11:37:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2022 11:37:29] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Aug/2022 11:38:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Aug/2022 11:38:09] "GET /favicon.ico HTTP/1.1" 404 -
